# %% [markdown]
# # CNN classification with more data

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.rcParams['axes.grid'] = True
plt.rcParams['axes.axisbelow'] = True
plt.rcParams['figure.dpi'] = 150

# %%
import torch
import torchvision
from torchvision.transforms import v2

transform = v2.Compose([
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True)
])
train_dataset = torchvision.datasets.STL10(split='train', root='~/scr10/', download=True)
test_dataset = torchvision.datasets.STL10(split='test', root='~/scr10/', download=True)
# Out:
# Downloading https://thor.robots.ox.ac.uk/dtd/dtd-r1.0.1.tar.gz to /home/jcolen/scr10/dtd/dtd-r1.0.1.tar.gz
#   1%|          | 4128768/625239812 [01:01<2:32:59, 67665.18it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 9
#       3 from torchvision.transforms import v2
#       5 transform = v2.Compose([
#       6     v2.ToImage(),
#       7     v2.ToDtype(torch.float32, scale=True)
#       8 ])
# ----> 9 train_dataset = torchvision.datasets.DTD(split='train', root='~/scr10/', download=True)
#      10 test_dataset = torchvision.datasets.DTD(split='test', root='~/scr10/', download=True)
#
# File /opt/conda/lib/python3.11/site-packages/torchvision/datasets/dtd.py:59, in DTD.__init__(self, root, split, partition, transform, target_transform, download)
#      56 self._images_folder = self._data_folder / "images"
#      58 if download:
# ---> 59     self._download()
#      61 if not self._check_exists():
#      62     raise RuntimeError("Dataset not found. You can use download=True to download it")
#
# File /opt/conda/lib/python3.11/site-packages/torchvision/datasets/dtd.py:100, in DTD._download(self)
#      98 if self._check_exists():
#      99     return
# --> 100 download_and_extract_archive(self._URL, download_root=str(self._base_folder), md5=self._MD5)
#
# File /opt/conda/lib/python3.11/site-packages/torchvision/datasets/utils.py:395, in download_and_extract_archive(url, download_root, extract_root, filename, md5, remove_finished)
#     392 if not filename:
#     393     filename = os.path.basename(url)
# --> 395 download_url(url, download_root, filename, md5)
#     397 archive = os.path.join(download_root, filename)
#     398 print(f"Extracting {archive} to {extract_root}")
#
# File /opt/conda/lib/python3.11/site-packages/torchvision/datasets/utils.py:132, in download_url(url, root, filename, md5, max_redirect_hops)
#     130 try:
#     131     print("Downloading " + url + " to " + fpath)
# --> 132     _urlretrieve(url, fpath)
#     133 except (urllib.error.URLError, OSError) as e:  # type: ignore[attr-defined]
#     134     if url[:5] == "https":
#
# File /opt/conda/lib/python3.11/site-packages/torchvision/datasets/utils.py:30, in _urlretrieve(url, filename, chunk_size)
#      28 with urllib.request.urlopen(urllib.request.Request(url, headers={"User-Agent": USER_AGENT})) as response:
#      29     with open(filename, "wb") as fh, tqdm(total=response.length) as pbar:
# ---> 30         while chunk := response.read(chunk_size):
#      31             fh.write(chunk)
#      32             pbar.update(len(chunk))
#
# File /opt/conda/lib/python3.11/http/client.py:473, in HTTPResponse.read(self, amt)
#     470 if self.length is not None and amt > self.length:
#     471     # clip the read to the "end of response"
#     472     amt = self.length
# --> 473 s = self.fp.read(amt)
#     474 if not s and amt:
#     475     # Ideally, we would raise IncompleteRead if the content-length
#     476     # wasn't satisfied, but it might break compatibility.
#     477     self._close_conn()
#
# File /opt/conda/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File /opt/conda/lib/python3.11/ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/conda/lib/python3.11/ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:
